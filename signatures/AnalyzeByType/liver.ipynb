# %% [markdown]
# # Liver and subtypes

# %%
import numpy as np
import pandas as pd
import time
import os
import pickle
import sys
from importlib import reload


from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from utils import CancerType

# %% [markdown]
# ## 1st iteration, inspect each subtype

# %%
liver = CancerType('Liver')

# %%
liver.countSubtypes()
# Out:
# [['81703' 371]
#  ['C22' 253]
#  ['None' 27]]

# %% [markdown]
# ```
# 8170/3: Hepatocellular carcinoma, NOS
# ```

# %%
code_remap = {
    '81703': 'Hepatocellular carcinoma',
    'C22': 'Not specified',
    'None': 'Not specified'
}

# %%
liver.relabel(code_remap)

# %%
liver.countSubtypes()
# Out:
# [['Hepatocellular carcinoma' 371]
#  ['Not specified' 280]]

# %%
liver.pcaTSNE()
# Out:
# PCA done! Time elapsed: 0.0654449462890625 seconds
# Cumulative explained variation for 50 principal components: 0.9307295134061506
# t-SNE done! Time elapsed: 4.586129903793335 seconds

# %%
liver.groupData()

# %%
liver.analyze([250, 90, -300, -100])
liver.dumpFiles()

# %%
liver.countData()
# Out:
# amp_genes	(184, 9)
# del_genes	(71, 9)
# genes	184
# high_amp_genes	(25, 9)
# low_amp_genes	(159, 9)
# high_del_genes	(7, 9)
# low_del_genes	(64, 9)
# high_amp_census	(2, 9)
# low_amp_census	(3, 9)
# amp_census	(5, 9)
# high_del_census	(0, 9)
# low_del_census	(3, 9)
# del_census	(3, 9)
# census	8

# %% [markdown]
# ### Hepatocellular carcinoma: 8170/3

# %%
subtype = 'Hepatocellular carcinoma'
liver.prepareSubtype(subtype)

# %%
liver.analyzeSubtype(subtype,[170,60, -190,-60])
liver.dumpSubtypeFiles(subtype)

# %%
liver.dumpSubtypeCounts()

# %% [markdown]
# ### conclusion

# %% [markdown]
# Only one subtype
