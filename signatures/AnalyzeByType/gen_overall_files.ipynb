# %% [markdown]
# Combine individual analyses in each subtype

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
import os
import pandas as pd
import numpy as np
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import preprocessing

# %% [markdown]
# ## Read files

# %%
genes = pd.read_csv('../../data/genes.tsv', sep='\t')
genes.columns = ['name', 'band', 'chr', 'start', 'end', 'symbol']

# %%
def file2record(f):
    df = pd.read_csv(f, sep='\t')
    df = df[['gene_id', 'cnv_scaled']].transpose()
    df.columns = df.iloc[0,:]
    df.columns.name = None
    df = df.iloc[[1]]
    df.index = ['-'.join([organ.name, subtype.name])]
    return df

# %%
path = '../../data/'
amps = []
dels = []

amps_hi = []
dels_hi = []

min_samples = 50
for organ in os.scandir(path):
    if organ.is_dir():
        print(organ.name)
        
        with open(os.path.join(organ, '_'.join([organ.name.lower(), 'counts.tsv']))) as fc:
            counts = pd.read_csv(fc, sep='\t')
            print(counts)
        
        for subtype in os.scandir(os.path.abspath(organ)):
            if subtype.is_dir():
                print('\t{}'.format(subtype.name))
                    
                if counts.loc[counts['name'] == subtype.name, 'count'].values[0] < min_samples:
                    print('\t\t Not enough samples: {}'.format(subtype.name))
                else:
                    
                    for f in os.scandir(os.path.abspath(subtype)):
                        if len(f.name.split('_')) == 4:
                            if 'amp_genes' in f.name:
                                print('\t\t{}'.format(f.name))
                                amps.append(file2record(f))

                            if 'del_genes' in f.name:
                                print('\t\t{}'.format(f.name))
                                dels.append(file2record(f))

                                
                        if 'high_amp_genes' in f.name:
                            print('\t\t{}'.format(f.name))
                            amps_hi.append(file2record(f))
                        if 'high_del_genes' in f.name:
                            print('\t\t{}'.format(f.name))
                            dels_hi.append(file2record(f))
# Out:
# Skin
#                    name  count
# 0          Bednar tumor     11
# 1  Epidermoid carcinoma     18
# 2          Keratinizing     11
# 3              Melanoma   1068
# 4         Not specified     50
# 5  Pagetoid reticulosis     32
# 	Bednar tumor
# 		 Not enough samples: Bednar tumor
# 	Melanoma
# 		skin_Melanoma_high_del_genes.tsv
# 		skin_Melanoma_amp_genes.tsv
# 		skin_Melanoma_del_genes.tsv
# 		skin_Melanoma_high_amp_genes.tsv
# 	Keratinizing
# 		 Not enough samples: Keratinizing
# 	Epidermoid carcinoma
# 		 Not enough samples: Epidermoid carcinoma
# 	Pagetoid reticulosis
# 		 Not enough samples: Pagetoid reticulosis
# Prostate
#              name  count
# 0  Adenocarcinoma    916
# 1       Carcinoma     16
# 2   Not specified    253
# 	Carcinoma
# 		 Not enough samples: Carcinoma
# 	Adenocarcinoma
# 		prostate_Adenocarcinoma_del_genes.tsv
# 		prostate_Adenocarcinoma_high_amp_genes.tsv
# 		prostate_Adenocarcinoma_amp_genes.tsv
# 		prostate_Adenocarcinoma_high_del_genes.tsv
# Lung
#                                                  name  count
# 0                               Acinar cell carcinoma     21
# 1                                      Adenocarcinoma   1212
# 2                             Adenosquamous carcinoma     16
# 3                         Bronchial adenoma carcinoid     17
# 4                  Bronchiolo-alveolar adenocarcinoma     24
# 5   Bronchiolo-alveolar carcinoma mixed mucinous a...     18
# 6          Bronchiolo-alveolar carcinoma non-mucinous     19
# 7                                           Carcinoma    138
# 8                             Mucinous adenocarcinoma     14
# 9                            Non-small cell carcinoma   1725
# 10                           Papillary adenocarcinoma     29
# 11                               Small cell carcinoma    155
# 12                            Squamous cell carcinoma    518
# 13                  Squamous cell carcinoma uncertain     12
# 	Carcinoma
# 		lung_Carcinoma_amp_genes.tsv
# 		lung_Carcinoma_high_del_genes.tsv
# 		lung_Carcinoma_del_genes.tsv
# 		lung_Carcinoma_high_amp_genes.tsv
# 	Adenocarcinoma
# 		lung_Adenocarcinoma_del_genes.tsv
# 		lung_Adenocarcinoma_high_del_genes.tsv
# 		lung_Adenocarcinoma_high_amp_genes.tsv
# 		lung_Adenocarcinoma_amp_genes.tsv
# Breast
#                                        name  count
# 0   Infiltrating duct and lobular carcinoma     28
# 1               Infiltrating duct carcinoma   5657
# 2                   Infiltrating duct mixed     14
# 3                    Inflammatory carcinoma     19
# 4                     Intraductal carcinoma     82
# 5      Intraductal micropapillary carcinoma     43
# 6                         Lobular carcinoma    201
# 7                     Metaplastic carcinoma     16
# 8                   Mucinous adenocarcinoma     15
# 9                             Not specified     89
# 10                    Pleomorphic carcinoma     14
# 	Infiltrating duct carcinoma
# 		breast_Infiltrating duct carcinoma_amp_genes.tsv
# 		breast_Infiltrating duct carcinoma_high_amp_genes.tsv
# 		breast_Infiltrating duct carcinoma_high_del_genes.tsv
# 		breast_Infiltrating duct carcinoma_del_genes.tsv
# 	Infiltrating duct mixed
# 		 Not enough samples: Infiltrating duct mixed
# 	Pleomorphic carcinoma
# 		 Not enough samples: Pleomorphic carcinoma
# 	Metaplastic carcinoma
# 		 Not enough samples: Metaplastic carcinoma
# 	Inflammatory carcinoma
# 		 Not enough samples: Inflammatory carcinoma
# 	Intraductal carcinoma
# 		breast_Intraductal carcinoma_del_genes.tsv
# 		breast_Intraductal carcinoma_high_del_genes.tsv
# 		breast_Intraductal carcinoma_amp_genes.tsv
# 		breast_Intraductal carcinoma_high_amp_genes.tsv
# 	Infiltrating duct and lobular carcinoma
# 		 Not enough samples: Infiltrating duct and lobular carcinoma
# 	Intraductal micropapillary carcinoma
# 		 Not enough samples: Intraductal micropapillary carcinoma
# 	Lobular carcinoma
# 		breast_Lobular carcinoma_high_amp_genes.tsv
# 		breast_Lobular carcinoma_amp_genes.tsv
# 		breast_Lobular carcinoma_high_del_genes.tsv
# 		breast_Lobular carcinoma_del_genes.tsv
# 	Mucinous adenocarcinoma
# 		 Not enough samples: Mucinous adenocarcinoma
# Kidney
#                                     name  count
# 0              Clear cell adenocarcinoma    930
# 1                          Not Specified     73
# 2                      Oxyphilic adenoma     17
# 3                   Renal cell carcinoma    323
# 4  Renal cell carcinoma chromophobe type     15
# 	Oxyphilic adenoma
# 		 Not enough samples: Oxyphilic adenoma
# 	Renal cell carcinoma
# 		kidney_Renal cell carcinoma_del_genes.tsv
# 		kidney_Renal cell carcinoma_high_del_genes.tsv
# 		kidney_Renal cell carcinoma_high_amp_genes.tsv
# 		kidney_Renal cell carcinoma_amp_genes.tsv
# 	Renal cell carcinoma chromophobe type
# 		 Not enough samples: Renal cell carcinoma chromophobe type
# Colon
#                              name  count
# 0                  Adenocarcinoma   1643
# 1  Adenocarcinoma intestinal type     53
# 2                         Adenoma     63
# 3         Mucinous adenocarcinoma     62
# 	Adenoma
# 		colon_Adenoma_high_amp_genes.tsv
# 		colon_Adenoma_amp_genes.tsv
# 		colon_Adenoma_del_genes.tsv
# 		colon_Adenoma_high_del_genes.tsv
# 	Adenocarcinoma
# 		colon_Adenocarcinoma_amp_genes.tsv
# 		colon_Adenocarcinoma_high_amp_genes.tsv
# 		colon_Adenocarcinoma_high_del_genes.tsv
# 		colon_Adenocarcinoma_del_genes.tsv
# 	Adenocarcinoma intestinal type
# 		colon_Adenocarcinoma intestinal type_high_del_genes.tsv
# 		colon_Adenocarcinoma intestinal type_del_genes.tsv
# 		colon_Adenocarcinoma intestinal type_amp_genes.tsv
# 		colon_Adenocarcinoma intestinal type_high_amp_genes.tsv
# 	Mucinous adenocarcinoma
# 		colon_Mucinous adenocarcinoma_high_del_genes.tsv
# 		colon_Mucinous adenocarcinoma_del_genes.tsv
# 		colon_Mucinous adenocarcinoma_high_amp_genes.tsv
# 		colon_Mucinous adenocarcinoma_amp_genes.tsv
# Cerebellum
#               name  count
# 0  Medulloblastoma   1708
# 	Medulloblastoma
# 		cerebellum_Medulloblastoma_high_amp_genes.tsv
# 		cerebellum_Medulloblastoma_amp_genes.tsv
# 		cerebellum_Medulloblastoma_del_genes.tsv
# 		cerebellum_Medulloblastoma_high_del_genes.tsv
# Stomach
#                                 name  count
# 0                     Adenocarcinoma    763
# 1             Adenocarcinoma in situ     19
# 2     Adenocarcinoma intestinal type     83
# 3                            Adenoma     17
# 4                          Carcinoma     19
# 5             Carcinoma diffuse type     57
# 6   Gastrointestinal stromal sarcoma    175
# 7            Mucinous adenocarcinoma     21
# 8                      Not specified     29
# 9         Signet ring cell carcinoma     16
# 10            Tubular adenocarcinoma     82
# 	Carcinoma
# 		 Not enough samples: Carcinoma
# 	Adenoma
# 		 Not enough samples: Adenoma
# 	Gastrointestinal stromal sarcoma
# 		stomach_Gastrointestinal stromal sarcoma_amp_genes.tsv
# 		stomach_Gastrointestinal stromal sarcoma_high_del_genes.tsv
# 		stomach_Gastrointestinal stromal sarcoma_del_genes.tsv
# 		stomach_Gastrointestinal stromal sarcoma_high_amp_genes.tsv
# 	Adenocarcinoma
# 		stomach_Adenocarcinoma_del_genes.tsv
# 		stomach_Adenocarcinoma_high_amp_genes.tsv
# 		stomach_Adenocarcinoma_amp_genes.tsv
# 		stomach_Adenocarcinoma_high_del_genes.tsv
# 	Carcinoma diffuse type
# 		stomach_Carcinoma diffuse type_amp_genes.tsv
# 		stomach_Carcinoma diffuse type_high_amp_genes.tsv
# 		stomach_Carcinoma diffuse type_del_genes.tsv
# 		stomach_Carcinoma diffuse type_high_del_genes.tsv
# 	Adenocarcinoma intestinal type
# 		stomach_Adenocarcinoma intestinal type_del_genes.tsv
# 		stomach_Adenocarcinoma intestinal type_high_amp_genes.tsv
# 		stomach_Adenocarcinoma intestinal type_amp_genes.tsv
# 		stomach_Adenocarcinoma intestinal type_high_del_genes.tsv
# 	Adenocarcinoma in situ
# 		 Not enough samples: Adenocarcinoma in situ
# 	Tubular adenocarcinoma
# 		stomach_Tubular adenocarcinoma_high_del_genes.tsv
# 		stomach_Tubular adenocarcinoma_del_genes.tsv
# 		stomach_Tubular adenocarcinoma_high_amp_genes.tsv
# 		stomach_Tubular adenocarcinoma_amp_genes.tsv
# 	Mucinous adenocarcinoma
# 		 Not enough samples: Mucinous adenocarcinoma
# 	Signet ring cell carcinoma
# 		 Not enough samples: Signet ring cell carcinoma
# Brain
#                               name  count
# 0                      Astrocytoma    339
# 1                       Ependymoma     49
# 2                           Glioma   1805
# 3                     Mixed glioma    162
# 4                Oligodendroglioma    326
# 5  Primitive neuroectodermal tumor     82
# 	Astrocytoma
# 		brain_Astrocytoma_del_genes.tsv
# 		brain_Astrocytoma_high_amp_genes.tsv
# 		brain_Astrocytoma_high_del_genes.tsv
# 		brain_Astrocytoma_amp_genes.tsv
# 	Ependymoma
# 		 Not enough samples: Ependymoma
# 	Glioma
# 		brain_Glioma_high_del_genes.tsv
# 		brain_Glioma_del_genes.tsv
# 		brain_Glioma_high_amp_genes.tsv
# 		brain_Glioma_amp_genes.tsv
# 	Primitive neuroectodermal tumor
# 		brain_Primitive neuroectodermal tumor_amp_genes.tsv
# 		brain_Primitive neuroectodermal tumor_high_del_genes.tsv
# 		brain_Primitive neuroectodermal tumor_del_genes.tsv
# 		brain_Primitive neuroectodermal tumor_high_amp_genes.tsv
# 	Oligodendroglioma
# 		brain_Oligodendroglioma_del_genes.tsv
# 		brain_Oligodendroglioma_high_del_genes.tsv
# 		brain_Oligodendroglioma_amp_genes.tsv
# 		brain_Oligodendroglioma_high_amp_genes.tsv
# 	Mixed glioma
# 		brain_Mixed glioma_del_genes.tsv
# 		brain_Mixed glioma_high_amp_genes.tsv
# 		brain_Mixed glioma_high_del_genes.tsv
# 		brain_Mixed glioma_amp_genes.tsv
# Liver
#                        name  count
# 0  Hepatocellular carcinoma    371
# 1             Not specified    280
# 	Hepatocellular carcinoma
# 		liver_Hepatocellular carcinoma_high_amp_genes.tsv
# 		liver_Hepatocellular carcinoma_amp_genes.tsv
# 		liver_Hepatocellular carcinoma_del_genes.tsv
# 		liver_Hepatocellular carcinoma_high_del_genes.tsv
# Ovary
#                    name  count
# 0        Adenocarcinoma    146
# 1             Carcinoma   1770
# 2  Mucinous cystadenoma    117
# 3         Not specified     72
# 	Carcinoma
# 		ovary_Carcinoma_high_del_genes.tsv
# 		ovary_Carcinoma_del_genes.tsv
# 		ovary_Carcinoma_high_amp_genes.tsv
# 		ovary_Carcinoma_amp_genes.tsv
# 	Adenocarcinoma
# 		ovary_Adenocarcinoma_high_amp_genes.tsv
# 		ovary_Adenocarcinoma_del_genes.tsv
# 		ovary_Adenocarcinoma_high_del_genes.tsv
# 		ovary_Adenocarcinoma_amp_genes.tsv
# 	Mucinous cystadenoma
# 		ovary_Mucinous cystadenoma_del_genes.tsv
# 		ovary_Mucinous cystadenoma_high_amp_genes.tsv
# 		ovary_Mucinous cystadenoma_amp_genes.tsv
# 		ovary_Mucinous cystadenoma_high_del_genes.tsv

# %% [markdown]
# ## Accumulate all muations

# %%
all_amps = pd.concat(amps, sort=False)
all_dels = pd.concat(dels, sort=False)

# all amps
all_amps = all_amps.fillna(0)
sum_amps = np.sum(all_amps, axis=0)
gene_amps = pd.DataFrame({'name': all_amps.columns, 'sum':sum_amps})
gene_amps = pd.merge(gene_amps, genes, how='left', on='name')

# all dels
all_dels = all_dels.fillna(0)
sum_dels = np.sum(all_dels, axis=0)
gene_dels = pd.DataFrame({'name': all_dels.columns, 'sum':sum_dels})
gene_dels = pd.merge(gene_dels, genes, how='left', on='name')

# scaling 
sum_all = np.concatenate((sum_amps.values, sum_dels.values))
sum_all_scaled = preprocessing.minmax_scale(np.abs(sum_all))
gene_amps['cnv_scaled'] = sum_all_scaled[:sum_amps.shape[0]]
gene_dels['cnv_scaled'] = -sum_all_scaled[sum_amps.shape[0]:]

# output
gene_amps.to_csv(path + '/amp_genes.tsv', sep='\t', index=False)
gene_dels.to_csv(path + '/del_genes.tsv', sep='\t', index=False)

# overlapping drivers
censusfile = '../data/Census_allThu Jan 16 08_07_54 2020.tsv'
census_genes = pd.read_csv(censusfile, sep='\t')

census_amps = gene_amps[gene_amps['symbol'].isin(census_genes['Gene Symbol'].values)]
census_dels = gene_dels[gene_dels['symbol'].isin(census_genes['Gene Symbol'].values)]

census_amps.to_csv(path + '/amp_census.tsv', sep='\t', index=False)
census_dels.to_csv(path + '/del_census.tsv', sep='\t', index=False)

# %% [markdown]
# ## Accumulate high mutations

# %%
all_amps_hi = pd.concat(amps_hi, sort=False)
all_dels_hi = pd.concat(dels_hi, sort=False)

# all amps_hi
all_amps_hi = all_amps_hi.fillna(0)
sum_amps_hi = np.sum(all_amps_hi, axis=0)
gene_amps_hi = pd.DataFrame({'name': all_amps_hi.columns, 'sum':sum_amps_hi})
gene_amps_hi = pd.merge(gene_amps_hi, genes, how='left', on='name')

# all dels_hi
all_dels_hi = all_dels_hi.fillna(0)
sum_dels_hi = np.sum(all_dels_hi, axis=0)
gene_dels_hi = pd.DataFrame({'name': all_dels_hi.columns, 'sum':sum_dels_hi})
gene_dels_hi = pd.merge(gene_dels_hi, genes, how='left', on='name')

# scaling 
sum_all = np.concatenate((sum_amps_hi.values, sum_dels_hi.values))
sum_all_scaled = preprocessing.minmax_scale(np.abs(sum_all))
gene_amps_hi['cnv_scaled'] = sum_all_scaled[:sum_amps_hi.shape[0]]
gene_dels_hi['cnv_scaled'] = -sum_all_scaled[sum_amps_hi.shape[0]:]

# output
gene_amps_hi.to_csv(path + '/high_amp_genes.tsv', sep='\t', index=False)
gene_dels_hi.to_csv(path + '/high_del_genes.tsv', sep='\t', index=False)

# overlapping drivers
census_amps_hi = gene_amps_hi[gene_amps_hi['symbol'].isin(census_genes['Gene Symbol'].values)]
census_dels_hi = gene_dels_hi[gene_dels_hi['symbol'].isin(census_genes['Gene Symbol'].values)]

census_amps_hi.to_csv(path + '/high_amp_census.tsv', sep='\t', index=False)
census_dels_hi.to_csv(path + '/high_del_census.tsv', sep='\t', index=False)

# %%
data = all_feat.loc[:, all_feat.columns != 'label']
data = data.fillna(0).values

# %%
col_sum = np.sum(data, axis=0)

# %%
gene_names = all_feat.columns [all_feat.columns != 'label'].values

# %%
gene_names
# Out:
# array(['ENSG00000143207', 'ENSG00000121454', 'ENSG00000116260', ...,
#        'ENSG00000141371', 'ENSG00000170836', 'ENSG00000062725'],
#       dtype=object)

# %%
gene_sums = pd.DataFrame({'name':gene_names, 'sum':col_sum})

# %%
gene_sums.head(10)
# Out:
#               name       sum
# 0  ENSG00000143207  8.681541
# 1  ENSG00000121454  8.760399
# 2  ENSG00000116260  8.756662
# 3  ENSG00000143337  8.704378
# 4  ENSG00000169905  8.711760
# 5  ENSG00000143340  8.743454
# 6  ENSG00000162782  8.732982
# 7  ENSG00000116218  8.721839
# 8  ENSG00000162779  8.745573
# 9  ENSG00000057252  8.733895

# %%
genes.columns = ['name', 'band', 'chro', 'start', 'end', 'symbol']

# %%
gene_sums = pd.merge(gene_sums, genes, how='left', on='name')

# %%
gene_sums = gene_sums.sort_values(['chro', 'band'])

# %%
gene_dels.loc[(gene_dels['chro'] == 16) & (gene_dels['scaled'] < -0.1), :].sort_values(['chro', 'start'])
# Out:
#                 name       sum    band  chro     start       end    symbol  \
# 357  ENSG00000213853 -1.845472  p13.13    16  10528422  10580632      EMP2
# 362  ENSG00000153060 -1.831165  p13.13    16  10627501  10694930     TEKT5
# 361  ENSG00000103274 -1.819490  p13.13    16  10743786  10769351     NUBP1
# 360  ENSG00000166676 -1.818313  p13.13    16  10760919  10818794    TVP23A
# 359  ENSG00000179583 -1.823028  p13.13    16  10866222  10943021     CIITA
# 358  ENSG00000182108 -1.821702  p13.13    16  10928891  10942468      DEXI
# 355  ENSG00000038532 -1.826033  p13.13    16  10944564  11182186   CLEC16A
# 354  ENSG00000175643 -1.805450  p13.13    16  11249619  11381662      RMI2
# 353  ENSG00000185338 -1.794677  p13.13    16  11254405  11256200     SOCS1
# 352  ENSG00000178279 -1.794677  p13.13    16  11267748  11269533      TNP2
# 356  ENSG00000122304 -1.794107  p13.13    16  11275639  11276480      PRM2
# 350  ENSG00000175646 -1.792853  p13.13    16  11280841  11281330      PRM1
# 349  ENSG00000188897 -1.816124  p13.13    16  11359845  11527245       NaN
# 348  ENSG00000189067 -1.791959  p13.13    16  11547722  11636381     LITAF
# 347  ENSG00000184602 -1.766925  p13.13    16  11668455  11679152       SNN
# 351  ENSG00000153066 -1.762466  p13.13    16  11679080  11742878   TXNDC11
# 346  ENSG00000122299 -2.457155  p13.13    16  11750586  11797258    ZC3H7A
# 345  ENSG00000171490 -2.443341  p13.13    16  11833850  11851580    RSL1D1
# 344  ENSG00000103342 -2.447590  p13.13    16  11868128  11916082     GSPT1
# 343  ENSG00000234719 -1.764135  p13.13    16  11927259  11976643    NPIPB2
# 342  ENSG00000048462 -1.764658  p13.13    16  11965210  11968068  TNFRSF17
# 341  ENSG00000048471 -2.636203  p13.13    16  11976734  12574287     SNX29
#
#        scaled
# 357 -0.108856
# 362 -0.107982
# 361 -0.107270
# 360 -0.107198
# 359 -0.107486
# 358 -0.107405
# 355 -0.107669
# 354 -0.106412
# 353 -0.105755
# 352 -0.105755
# 356 -0.105720
# 350 -0.105643
# 349 -0.107064
# 348 -0.105589
# 347 -0.104060
# 351 -0.103788
# 346 -0.146201
# 345 -0.145358
# 344 -0.145617
# 343 -0.103890
# 342 -0.103922
# 341 -0.157133

# %%
gene_dels.loc[(gene_dels['chro'] == 16) & (gene_dels['band'] == 'p13.13'), :].sort_values(['chro', 'start'])['symbol']
# Out:
# 357        EMP2
# 362       TEKT5
# 361       NUBP1
# 360      TVP23A
# 359       CIITA
# 358        DEXI
# 355     CLEC16A
# 354        RMI2
# 353       SOCS1
# 352        TNP2
# 356        PRM2
# 350        PRM1
# 349         NaN
# 348       LITAF
# 347         SNN
# 351     TXNDC11
# 346      ZC3H7A
# 345      RSL1D1
# 344       GSPT1
# 343      NPIPB2
# 342    TNFRSF17
# 341       SNX29
# Name: symbol, dtype: object

# %%
genes
# Out:
#         Gene stable ID Karyotype band  Chromosome/scaffold name  \
# 0      ENSG00000117036          q23.1                         1
# 1      ENSG00000253831          q23.1                         1
# 2      ENSG00000132694          q23.1                         1
# 3      ENSG00000160838          q23.1                         1
# 4      ENSG00000187800          q23.1                         1
# ...                ...            ...                       ...
# 18745  ENSG00000148053         q21.33                         9
# 18746  ENSG00000125484         q34.13                         9
# 18747  ENSG00000125485         q34.13                         9
# 18748  ENSG00000165698         q34.13                         9
# 18749  ENSG00000165695         q34.13                         9
#
#        Gene start (bp)  Gene end (bp) HGNC symbol
# 0            157121191      157138474        ETV3
# 1            157092043      157112412       ETV3L
# 2            156934840      157045370    ARHGEF11
# 3            156920632      156933094      LRRC71
# 4            156893698      156916434       PEAR1
# ...                ...            ...         ...
# 18745         84668551       85027070       NTRK2
# 18746        132670035      132694953      GTF3C4
# 18747        132592997      132670401       DDX31
# 18748        132878027      132890201      SPACA9
# 18749        132725578      132878777         AK8
#
# [18750 rows x 6 columns]
