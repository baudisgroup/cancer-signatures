# %% [markdown]
# # Prostate and subtypes

# %%
import numpy as np
import pandas as pd
import time
import os
import pickle
import sys
from importlib import reload


from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from utils import CancerType

# %% [markdown]
# ## 1st iteration, inspect each subtype

# %%
prostate = CancerType('Prostate')

# %%
prostate.countSubtypes()
# Out:
# [['80103' 16]
#  ['81403' 916]
#  ['C61' 253]]

# %% [markdown]
# ```
# 8010/3: Carcinoma, NOS
# 8140/3: Adenocarcinoma
#  ```

# %%
code_remap = {
'80103': 'Carcinoma',
'81403': 'Adenocarcinoma',
'C61': 'Not specified'
}

# %%
prostate.relabel(code_remap)

# %%
prostate.countSubtypes()
# Out:
# [['Adenocarcinoma' 916]
#  ['Carcinoma' 16]
#  ['Not specified' 253]]

# %%
prostate.pcaTSNE()
# Out:
# PCA done! Time elapsed: 0.07859992980957031 seconds
# Cumulative explained variation for 50 principal components: 0.9022248536302369
# t-SNE done! Time elapsed: 9.10200810432434 seconds

# %%
prostate.groupData()

# %%
prostate.analyze([200, 120, -230, -120])
prostate.dumpFiles()

# %%
prostate.countData()
# Out:
# amp_genes	(93, 9)
# del_genes	(47, 9)
# genes	93
# high_amp_genes	(13, 9)
# low_amp_genes	(80, 9)
# high_del_genes	(15, 9)
# low_del_genes	(32, 9)
# high_amp_census	(1, 9)
# low_amp_census	(2, 9)
# amp_census	(3, 9)
# high_del_census	(0, 9)
# low_del_census	(1, 9)
# del_census	(1, 9)
# census	4

# %% [markdown]
# ### Carcinoma: 8010/3

# %%
subtype = 'Carcinoma'
prostate.prepareSubtype(subtype)

# %%
prostate.analyzeSubtype(subtype,[10,2.5, -5,-3])
prostate.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Adenocarcinoma: 8140/3

# %%
subtype = 'Adenocarcinoma'
prostate.prepareSubtype(subtype)

# %%
prostate.analyzeSubtype(subtype,[160,90, -250,-100])
prostate.dumpSubtypeFiles(subtype)

# %%
prostate.dumpSubtypeCounts()

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Two different sub-types
