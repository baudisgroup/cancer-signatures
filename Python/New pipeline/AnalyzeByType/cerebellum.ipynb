# %% [markdown]
# # Cerebellum and subtypes

# %%
import numpy as np
import pandas as pd
import time
import os
import pickle
import sys
from importlib import reload


from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from utils import CancerType

# %% [markdown]
# ## 1st iteration, inspect each subtype

# %%
cerebellum = CancerType('Cerebellum')

# %%
cerebellum.countSubtypes()
# Out:
# [['94703' 1573]
#  ['94713' 72]
#  ['94743' 37]
#  ['C71.6' 26]]

# %% [markdown]
# ```
# 9470/3: Medulloblastoma, NOS
# 9471/3: Desmoplastic nodular medulloblastoma
# 9474/3: Large cell medulloblastoma
# ```

# %%
code_remap = {
    '94703': 'Medulloblastoma',
    '94713': 'Desmoplastic nodular medulloblastoma',
    '94743': 'Large cell medulloblastoma',
    'C71.6': 'Medulloblastoma'
}

# %%
cerebellum.relabel(code_remap)

# %%
cerebellum.countSubtypes()
# Out:
# [['Desmoplastic nodular medulloblastoma' 72]
#  ['Large cell medulloblastoma' 37]
#  ['Medulloblastoma' 1599]]

# %%
cerebellum.dumpSubtypeCounts()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-2afb48603222> in <module>
# ----> 1 cerebellum.dumpSubtypeCounts()
#
# ~/Desktop/projects/new landscape/Python/New pipeline/AnalyzeByType/utils.py in dumpSubtypeCounts(self)
#     364         counts = pd.DataFrame(np.array(np.unique(self.labels, return_counts=True)).T, columns=['name','count'])
#     365         path = '{}{}/{}_counts.tsv'.format(CancerType.outputpath, self.type, self.type.lower())
# --> 366         counts.to_csv(path, index=False, sep='\t')
#     367
#     368
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
# ...

# %%
cerebellum.pcaTSNE()
# Out:
# PCA done! Time elapsed: 0.09557604789733887 seconds
# Cumulative explained variation for 50 principal components: 0.955552556347151
# t-SNE done! Time elapsed: 12.590229034423828 seconds

# %%
cerebellum.groupData()

# %%
cerebellum.analyze([500, 200, -500, -220])
cerebellum.dumpFiles()

# %%
cerebellum.countData()
# Out:
# amp_genes	(92, 9)
# del_genes	(56, 9)
# genes	92
# high_amp_genes	(15, 9)
# low_amp_genes	(77, 9)
# high_del_genes	(13, 9)
# low_del_genes	(43, 9)
# high_amp_census	(0, 9)
# low_amp_census	(2, 9)
# amp_census	(2, 9)
# high_del_census	(0, 9)
# low_del_census	(3, 9)
# del_census	(3, 9)
# census	5

# %% [markdown]
# ### Medulloblastoma:  9470/3

# %%
subtype = 'Medulloblastoma'
cerebellum.prepareSubtype(subtype)

# %%
cerebellum.analyzeSubtype(subtype,[300,180, -480,-250])
cerebellum.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Desmoplastic nodular medulloblastoma: 9471/3

# %%
subtype = 'Desmoplastic nodular medulloblastoma'
cerebellum.prepareSubtype(subtype)

# %%
cerebellum.analyzeSubtype(subtype,[15,6, -18,-11])
cerebellum.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Large cell medulloblastoma: 9474/3

# %%
subtype = 'Large cell medulloblastoma'
cerebellum.prepareSubtype(subtype)

# %%
cerebellum.analyzeSubtype(subtype,[10,6, -9,-4])
cerebellum.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### conclusion

# %% [markdown]
# All subtypes are similiar, combine all

# %% [markdown]
# ## Second interation of label subgroups

# %%
cerebellum = CancerType('Cerebellum')
cerebellum.countSubtypes()
# Out:
# [['94703' 1573]
#  ['94713' 72]
#  ['94743' 37]
#  ['C71.6' 26]]

# %%
code_remap = {
    '94703': 'Medulloblastoma',
    '94713': 'Medulloblastoma',
    '94743': 'Medulloblastoma',
    'C71.6': 'Medulloblastoma'
}

# %%
cerebellum.relabel(code_remap)
cerebellum.countSubtypes()
cerebellum.dumpSubtypeCounts()
# Out:
# [['Medulloblastoma' 1708]]

# %% [markdown]
# ### Medulloblastoma:  9470/3, 9471/3, 9474/3

# %%
subtype = 'Medulloblastoma'
cerebellum.prepareSubtype(subtype)

# %%
cerebellum.analyzeSubtype(subtype,[500,190, -500,-220])
cerebellum.dumpSubtypeFiles(subtype)
