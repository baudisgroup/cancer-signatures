# %% [markdown]
# # Ovary and subtypes

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
import numpy as np
import pandas as pd
import time
import os
import pickle
import sys
from importlib import reload


from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from utils import CancerType

# %%
reload(sys.modules['utils'])
from utils import CancerType

# %% [markdown]
# ## First label grouping

# %% [markdown]
# ### Initialization

# %%
ovary = CancerType('Ovary')

# %%
ovary.labels
# Out:
# array(['84413', '84413', '84413', ..., '84421', '84421', '84421'],
#       dtype=object)

# %%
ovary.countSubtypes()
# Out:
# [['80103' 761]
#  ['81403' 111]
#  ['83103' 24]
#  ['83803' 11]
#  ['84413' 964]
#  ['84421' 45]
#  ['84700' 57]
#  ['84800' 60]
#  ['C48.2' 13]
#  ['C56' 38]
#  ['None' 21]]

# %% [markdown]
# ```
# 8010/3 Carcinoma
# 8140/3 Adenocarcinoma
# 8310/3 Clear Cell Adenocarcinoma
# 8380/3 Endometrioid adenocarcinoma
# 8441/3 Serous carcinoma
# 8442/1 Serous tumor
# 8470/0 Mucinous cystadenoma
# 8480/0 Mucinous adenoma
# ```

# %%
code_remap = {'80103':'Carcinoma', 
              '81403':'Adenocarcinoma', 
              '83103':'Adenocarcinoma', 
              '83803':'Adenocarcinoma',
              '84413':'Serous carcinoma',
              '84421':'Serous carcinoma',
              '84700':'Mucinous cystadenoma',
              '84800':'Mucinous cystadenoma',
              'C48.2':'Not specified',
              'C56':'Not specified',
              'None':'Not specified'}

# %%
ovary.relabel(code_remap)

# %%
ovary.countSubtypes()
# Out:
# [['Adenocarcinoma' 146]
#  ['Carcinoma' 761]
#  ['Mucinous cystadenoma' 117]
#  ['Not specified' 72]
#  ['Serous carcinoma' 1009]]

# %%
ovary.pcaTSNE()
# Out:
# PCA done! Time elapsed: 0.23465871810913086 seconds
# Cumulative explained variation for 50 principal components: 0.8444829028594438
# t-SNE done! Time elapsed: 18.824793815612793 seconds

# %%
ovary.groupData()

# %%
ovary.analyze([900, 450, -1000, -300])
ovary.dumpFiles()

# %%
ovary.countData()
# Out:
# amp_genes	(510, 9)
# del_genes	(401, 9)
# genes	510
# high_amp_genes	(30, 9)
# low_amp_genes	(480, 9)
# high_del_genes	(43, 9)
# low_del_genes	(358, 9)
# high_amp_census	(4, 9)
# low_amp_census	(16, 9)
# amp_census	(20, 9)
# high_del_census	(2, 9)
# low_del_census	(22, 9)
# del_census	(24, 9)
# census	44

# %% [markdown]
# ### Carcinoma: 8010/3

# %%
subtype = 'Carcinoma'
ovary.prepareSubtype(subtype)

# %%
ovary.analyzeSubtype(subtype,[270,140, -350,-150])
ovary.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Adenocarcinoma: 8140/3, 8310/3, 8380/3

# %%
subtype = 'Adenocarcinoma'
ovary.prepareSubtype(subtype)

# %%
ovary.analyzeSubtype(subtype,[45,30, -70,-35])
ovary.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Serous carcinoma: 8441/3, 8442/1

# %%
subtype = 'Serous carcinoma'
ovary.prepareSubtype(subtype)

# %%
ovary.analyzeSubtype(subtype,[500,250, -600,-200])
ovary.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Mucinous cystadenoma: 8470/0, 8480/0

# %%
subtype = 'Mucinous cystadenoma'
ovary.prepareSubtype(subtype)

# %%
ovary.analyzeSubtype(subtype,[5,3, -5,-3])
ovary.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Conclusion
# After comparing signatures, "Carcinoma" and "Serous carcinoma" are almost identicial. Merge the two labels to "Carcinoma"

# %% [markdown]
# ## Second label grouping

# %% [markdown]
# ### Initialization

# %%
ovary = CancerType('Ovary')

# %%
ovary.countSubtypes()
# Out:
# [['80103' 761]
#  ['81403' 111]
#  ['83103' 24]
#  ['83803' 11]
#  ['84413' 964]
#  ['84421' 45]
#  ['84700' 57]
#  ['84800' 60]
#  ['C48.2' 13]
#  ['C56' 38]
#  ['None' 21]]

# %% [markdown]
# Merge "Carcinom" and "Serous Carcinoma"

# %%
code_remap = {'80103':'Carcinoma', 
              '81403':'Adenocarcinoma', 
              '83103':'Adenocarcinoma', 
              '83803':'Adenocarcinoma',
              '84413':'Carcinoma',
              '84421':'Carcinoma',
              '84700':'Mucinous cystadenoma',
              '84800':'Mucinous cystadenoma',
              'C48.2':'Not specified',
              'C56':'Not specified',
              'None':'Not specified'}

# %%
ovary.relabel(code_remap)

# %%
ovary.countSubtypes()
# Out:
# [['Adenocarcinoma' 146]
#  ['Carcinoma' 1770]
#  ['Mucinous cystadenoma' 117]
#  ['Not specified' 72]]

# %%
ovary.pcaTSNE()
# Out:
# PCA done! Time elapsed: 0.11443686485290527 seconds
# Cumulative explained variation for 50 principal components: 0.8648467447873336
# t-SNE done! Time elapsed: 19.387759923934937 seconds

# %%
ovary.groupData()

# %%
ovary.analyze([800, 420, -1000, -400])
#ovary.dumpFiles()

# %%
ovary.countData()
# Out:
# amp_genes	(181, 9)
# del_genes	(92, 9)
# genes	181
# high_amp_genes	(14, 9)
# low_amp_genes	(167, 9)
# high_del_genes	(11, 9)
# low_del_genes	(81, 9)
# high_amp_census	(1, 9)
# low_amp_census	(5, 9)
# amp_census	(6, 9)
# high_del_census	(0, 9)
# low_del_census	(3, 9)
# del_census	(3, 9)
# census	9

# %% [markdown]
# ### Carcinoma: 8010/3, 8441/3, 8442/1

# %%
subtype = 'Carcinoma'
ovary.prepareSubtype(subtype)

# %%
ovary.analyzeSubtype(subtype,[700,390, -900,-300])
ovary.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Adenocarcinoma: 8140/3, 8310/3, 8380/3

# %%
subtype = 'Adenocarcinoma'
ovary.prepareSubtype(subtype)

# %%
ovary.analyzeSubtype(subtype,[45,30, -65,-35])
ovary.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Mucinous cystadenoma: 8470/0, 8480/0

# %%
subtype = 'Mucinous cystadenoma'
ovary.prepareSubtype(subtype)

# %%
ovary.analyzeSubtype(subtype,[5,3, -5,-3])
ovary.dumpSubtypeFiles(subtype)

# %%
ovary.dumpSubtypeCounts()
