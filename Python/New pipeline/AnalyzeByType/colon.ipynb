# %% [markdown]
# # Colon and subtypes

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
import numpy as np
import pandas as pd
import time
import os
import pickle
import sys
from importlib import reload


from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from utils import CancerType

# %% [markdown]
# ## Iteration 1, individual subtypes

# %%
colon = CancerType('Colon')

# %%
colon.countSubtypes()
# Out:
# [['81400' 63]
#  ['81403' 1643]
#  ['81443' 53]
#  ['84803' 62]]

# %% [markdown]
# ```
# 8140/0: Adenoma, NOS
# 8140/3: Adenocarcinoma, NOS
# 8144/3: Adenocarcinoma, intestinal type
# 8480/3: Mucinous adenocarcinoma
# ```

# %%
code_remap = {
'81400': 'Adenoma',
'81403': 'Adenocarcinoma',
'81443': 'Adenocarcinoma intestinal type',
'84803': 'Mucinous adenocarcinoma'
}

# %%
colon.relabel(code_remap)

# %%
colon.countSubtypes()
# Out:
# [['Adenocarcinoma' 1643]
#  ['Adenocarcinoma intestinal type' 53]
#  ['Adenoma' 63]
#  ['Mucinous adenocarcinoma' 62]]

# %%
colon.pcaTSNE()
# Out:
# PCA done! Time elapsed: 0.1028130054473877 seconds
# Cumulative explained variation for 50 principal components: 0.9190404508427121
# t-SNE done! Time elapsed: 14.948855876922607 seconds

# %%
colon.groupData()

# %%
colon.analyze([800, 400, -1000, -500])
colon.dumpFiles()

# %%
colon.countData()
# Out:
# amp_genes	(92, 9)
# del_genes	(29, 9)
# genes	92
# high_amp_genes	(12, 9)
# low_amp_genes	(80, 9)
# high_del_genes	(6, 9)
# low_del_genes	(23, 9)
# high_amp_census	(2, 9)
# low_amp_census	(2, 9)
# amp_census	(4, 9)
# high_del_census	(0, 9)
# low_del_census	(1, 9)
# del_census	(1, 9)
# census	5

# %% [markdown]
# ### Adenoma: 8140/0

# %%
subtype = 'Adenoma'
colon.prepareSubtype(subtype)

# %%
colon.analyzeSubtype(subtype,[12,6, -12,-7])
colon.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Adenocarcinoma: 8140/3

# %%
subtype = 'Adenocarcinoma'
colon.prepareSubtype(subtype)

# %%
colon.analyzeSubtype(subtype,[700,400, -1000,-450])
colon.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Adenocarcinoma intestinal type: 8144/3

# %%
subtype = 'Adenocarcinoma intestinal type'
colon.prepareSubtype(subtype)

# %%
colon.analyzeSubtype(subtype,[15,8, -22,-8])
colon.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Mucinous adenocarcinoma: 8480/3

# %%
subtype = 'Mucinous adenocarcinoma'
colon.prepareSubtype(subtype)

# %%
colon.analyzeSubtype(subtype,[17,10, -25,-11])
colon.dumpSubtypeFiles(subtype)

# %%
colon.dumpSubtypeCounts()

# %% [markdown]
# ### Conclusion

# %% [markdown]
# All subtypes are similar, but with some sublte difference. No merging for now.
