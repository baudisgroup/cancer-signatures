# %% [markdown]
# # Colon and subtypes

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
import numpy as np
import pandas as pd
import time
import os
import pickle
import sys
from importlib import reload


from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from utils import CancerType

# %% [markdown]
# ## Iteration 1, individual subtypes

# %%
colon = CancerType('Colon')

# %%
colon.countSubtypes()
# Out:
# [['81400' 63]
#  ['81403' 1643]
#  ['81443' 53]
#  ['84803' 62]]

# %% [markdown]
# ```
# 8140/0: Adenoma, NOS
# 8140/3: Adenocarcinoma, NOS
# 8144/3: Adenocarcinoma, intestinal type
# 8480/3: Mucinous adenocarcinoma
# ```

# %%
code_remap = {
'81400': 'Adenoma',
'81403': 'Adenocarcinoma',
'81443': 'Adenocarcinoma intestinal type',
'84803': 'Mucinous adenocarcinoma'
}

# %%
colon.relabel(code_remap)

# %%
colon.countSubtypes()
# Out:
# [['Adenocarcinoma' 1643]
#  ['Adenocarcinoma intestinal type' 53]
#  ['Adenoma' 63]
#  ['Mucinous adenocarcinoma' 62]]

# %%
colon.dumpSubtypeCounts()

# %%
colon.pcaTSNE()
# Out:
# PCA done! Time elapsed: 0.2162623405456543 seconds
# Cumulative explained variation for 50 principal components: 0.9103537199797402
# t-SNE done! Time elapsed: 14.549569606781006 seconds

# %%
colon.groupData()

# %%
colon.analyze([800, 400, -1000, -500])
colon.dumpFiles()

# %%
colon.countData()
# Out:
# amp_genes	(278, 9)
# del_genes	(119, 9)
# genes	278
# high_amp_genes	(35, 9)
# low_amp_genes	(243, 9)
# high_del_genes	(28, 9)
# low_del_genes	(91, 9)
# high_amp_census	(5, 9)
# low_amp_census	(11, 9)
# amp_census	(16, 9)
# high_del_census	(1, 9)
# low_del_census	(5, 9)
# del_census	(6, 9)
# census	22

# %% [markdown]
# ### Adenoma: 8140/0

# %%
subtype = 'Adenoma'
colon.prepareSubtype(subtype)

# %%
colon.analyzeSubtype(subtype,[12,5, -12,-7])
colon.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Adenocarcinoma: 8140/3

# %%
subtype = 'Adenocarcinoma'
colon.prepareSubtype(subtype)

# %%
colon.analyzeSubtype(subtype,[700,400, -1000,-450])
colon.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Adenocarcinoma intestinal type: 8144/3

# %%
subtype = 'Adenocarcinoma intestinal type'
colon.prepareSubtype(subtype)

# %%
colon.analyzeSubtype(subtype,[15,8, -22,-8])
colon.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Mucinous adenocarcinoma: 8480/3

# %%
subtype = 'Mucinous adenocarcinoma'
colon.prepareSubtype(subtype)

# %%
colon.analyzeSubtype(subtype,[17,10, -25,-11])
colon.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Conclusion

# %% [markdown]
# All subtypes are similar, but with some sublte difference. No merging for now.
