# %% [markdown]
# # Prostate and subtypes

# %%
import numpy as np
import pandas as pd
import time
import os
import pickle
import sys
from importlib import reload


from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from utils import CancerType

# %% [markdown]
# ## 1st iteration, inspect each subtype

# %%
prostate = CancerType('Prostate')

# %%
prostate.countSubtypes()
# Out:
# [['80103' 16]
#  ['81403' 916]
#  ['C61' 253]]

# %% [markdown]
# ```
# 8010/3: Carcinoma, NOS
# 8140/3: Adenocarcinoma
#  ```

# %%
code_remap = {
'80103': 'Carcinoma',
'81403': 'Adenocarcinoma',
'C61': 'Not specified'
}

# %%
prostate.relabel(code_remap)

# %%
prostate.countSubtypes()
# Out:
# [['Adenocarcinoma' 916]
#  ['Carcinoma' 16]
#  ['Not specified' 253]]

# %%
prostate.pcaTSNE()
# Out:
# PCA done! Time elapsed: 0.17580389976501465 seconds
# Cumulative explained variation for 50 principal components: 0.8848628845993589
# t-SNE done! Time elapsed: 10.05769395828247 seconds

# %%
prostate.groupData()

# %%
prostate.analyze([200, 120, -230, -120])
prostate.dumpFiles()

# %%
prostate.countData()
# Out:
# amp_genes	(272, 9)
# del_genes	(178, 9)
# genes	272
# high_amp_genes	(42, 9)
# low_amp_genes	(230, 9)
# high_del_genes	(57, 9)
# low_del_genes	(121, 9)
# high_amp_census	(4, 9)
# low_amp_census	(11, 9)
# amp_census	(15, 9)
# high_del_census	(3, 9)
# low_del_census	(5, 9)
# del_census	(8, 9)
# census	23

# %% [markdown]
# ### Carcinoma: 8010/3

# %%
subtype = 'Carcinoma'
prostate.prepareSubtype(subtype)

# %%
prostate.analyzeSubtype(subtype,[10,2.5, -5,-3])
prostate.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Adenocarcinoma: 8140/3

# %%
subtype = 'Adenocarcinoma'
prostate.prepareSubtype(subtype)

# %%
prostate.analyzeSubtype(subtype,[160,90, -250,-100])
prostate.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Two different sub-types
