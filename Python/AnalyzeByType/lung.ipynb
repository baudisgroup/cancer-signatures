# %% [markdown]
# # Lung and subtypes

# %%
import numpy as np
import pandas as pd
import time
import os
import pickle
import sys
from importlib import reload


from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from utils import CancerType

# %% [markdown]
# ## 1st iteration, inspect each subtype

# %%
lung = CancerType('Lung')

# %%
lung.countSubtypes()
# Out:
# [['80103' 84]
#  ['80123' 54]
#  ['80413' 155]
#  ['80463' 1725]
#  ['80701' 12]
#  ['80703' 518]
#  ['81403' 1103]
#  ['82403' 17]
#  ['82503' 24]
#  ['82523' 19]
#  ['82543' 18]
#  ['82553' 109]
#  ['82603' 29]
#  ['84803' 14]
#  ['85503' 21]
#  ['85603' 16]]

# %% [markdown]
# ```
# 8010/3: Carcinoma, NOS
# 8012/3: Large cell carcinoma, NOS
# 8041/3: Small cell carcinoma, NOS
# 8046/3: Non-small cell carcinoma
# 8070/1: Squamous cell carcinoma, uncertain
# 8070/3: Squamous cell carcinoma, NOS
# 8140/3: Adenocarcinoma
# 8240/3: Bronchial adenoma, carcinoid
# 8250/3: Bronchiolo-alveolar adenocarcinoma, NOS
# 8252/3: Bronchiolo-alveolar carcinoma, non-mucinous
# 8254/3: Bronchiolo-alveolar carcinoma, mixed mucinous and non-mucinous
# 8255/3: Adenocarcinoma with mixed subtypes
# 8260/3: Papillary adenocarcinoma, NOS
# 8480/3: Mucinous adenocarcinoma
# 8550/3: Acinar cell carcinoma
# 8560/3: Adenosquamous carcinoma
#  ```

# %%
code_remap = {
'80103': 'Carcinoma',
'80123': 'Large cell carcinoma',
'80413': 'Small cell carcinoma',
'80463': 'Non-small cell carcinoma',
'80701': 'Squamous cell carcinoma uncertain',
'80703': 'Squamous cell carcinoma',
'81403': 'Adenocarcinoma',
'82403': 'Bronchial adenoma carcinoid',
'82503': 'Bronchiolo-alveolar adenocarcinoma',
'82523': 'Bronchiolo-alveolar carcinoma non-mucinous',
'82543': 'Bronchiolo-alveolar carcinoma mixed mucinous and non-mucinous',
'82553': 'Adenocarcinoma with mixed subtypes',
'82603': 'Papillary adenocarcinoma',
'84803': 'Mucinous adenocarcinoma',
'85503': 'Acinar cell carcinoma',
'85603': 'Adenosquamous carcinoma'
}

# %%
lung.relabel(code_remap)

# %%
lung.countSubtypes()
# Out:
# [['Acinar cell carcinoma' 21]
#  ['Adenocarcinoma' 1103]
#  ['Adenocarcinoma with mixed subtypes' 109]
#  ['Adenosquamous carcinoma' 16]
#  ['Bronchial adenoma carcinoid' 17]
#  ['Bronchiolo-alveolar adenocarcinoma' 24]
#  ['Bronchiolo-alveolar carcinoma mixed mucinous and non-mucinous' 18]
#  ['Bronchiolo-alveolar carcinoma non-mucinous' 19]
#  ['Carcinoma' 84]
#  ['Large cell carcinoma' 54]
#  ['Mucinous adenocarcinoma' 14]
#  ['Non-small cell carcinoma' 1725]
#  ['Papillary adenocarcinoma' 29]
#  ['Small cell carcinoma' 155]
#  ['Squamous cell carcinoma' 518]
#  ['Squamous cell carcinoma uncertain' 12]]

# %%
lung.pcaTSNE()
# Out:
# PCA done! Time elapsed: 0.37581896781921387 seconds
# Cumulative explained variation for 50 principal components: 0.8565969161871225
# t-SNE done! Time elapsed: 34.95054793357849 seconds

# %%
lung.groupData()

# %%
lung.analyze([1200, 700, -1350, -800])
lung.dumpFiles()

# %%
lung.countData()
# Out:
# amp_genes	(470, 9)
# del_genes	(250, 9)
# genes	470
# high_amp_genes	(65, 9)
# low_amp_genes	(405, 9)
# high_del_genes	(21, 9)
# low_del_genes	(229, 9)
# high_amp_census	(5, 9)
# low_amp_census	(14, 9)
# amp_census	(19, 9)
# high_del_census	(1, 9)
# low_del_census	(12, 9)
# del_census	(13, 9)
# census	32

# %% [markdown]
# ### Carcinoma: 8010/3

# %%
subtype = 'Carcinoma'
lung.prepareSubtype(subtype)

# %%
lung.analyzeSubtype(subtype,[38,20, -48,-28])
lung.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Large cell carcinoma: 8012/3

# %%
subtype = 'Large cell carcinoma'
lung.prepareSubtype(subtype)

# %%
lung.analyzeSubtype(subtype,[20,10, -19,-8])
lung.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Small cell carcinoma: 8041/3

# %%
subtype = 'Small cell carcinoma'
lung.prepareSubtype(subtype)

# %%
lung.analyzeSubtype(subtype,[60,25, -65,-40])
lung.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Non-small cell carcinoma: 8046/3

# %%
subtype = 'Non-small cell carcinoma'
lung.prepareSubtype(subtype)

# %%
lung.analyzeSubtype(subtype,[500,350, -650,-300])
lung.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Squamous cell carcinoma uncertain: 8070/1

# %%
subtype = 'Squamous cell carcinoma uncertain'
lung.prepareSubtype(subtype)

# %%
lung.analyzeSubtype(subtype,[5,2, -5,-2.5])
lung.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Squamous cell carcinoma: 8070/3

# %%
subtype = 'Squamous cell carcinoma'
lung.prepareSubtype(subtype)

# %%
lung.analyzeSubtype(subtype,[150,90, -170,-80])
lung.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Adenocarcinoma: 8140/3

# %%
subtype = 'Adenocarcinoma'
lung.prepareSubtype(subtype)

# %%
lung.analyzeSubtype(subtype,[300,200, -450,-250])
lung.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Bronchial adenoma carcinoid: 8240/3

# %%
subtype = 'Bronchial adenoma carcinoid'
lung.prepareSubtype(subtype)

# %%
lung.analyzeSubtype(subtype,[2.5,1, -7,-5])
lung.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Bronchiolo-alveolar adenocarcinoma: 8250/3

# %%
subtype = 'Bronchiolo-alveolar adenocarcinoma'
lung.prepareSubtype(subtype)

# %%
lung.analyzeSubtype(subtype,[5,3, -13,-7])
lung.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Bronchiolo-alveolar carcinoma non-mucinous: 8252/3

# %%
subtype = 'Bronchiolo-alveolar carcinoma non-mucinous'
lung.prepareSubtype(subtype)

# %%
lung.analyzeSubtype(subtype,[9,4, -10,-7])
lung.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Bronchiolo-alveolar carcinoma mixed mucinous and non-mucinous: 8254/3

# %%
subtype = 'Bronchiolo-alveolar carcinoma mixed mucinous and non-mucinous'
lung.prepareSubtype(subtype)

# %%
lung.analyzeSubtype(subtype,[13,5, -30,-15])
lung.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Adenocarcinoma with mixed subtypes: 8255/3

# %%
subtype = 'Adenocarcinoma with mixed subtypes'
lung.prepareSubtype(subtype)

# %%
lung.analyzeSubtype(subtype,[38,20, -55,-34])
lung.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Papillary adenocarcinoma: 8260/3

# %%
subtype = 'Papillary adenocarcinoma'
lung.prepareSubtype(subtype)

# %%
lung.analyzeSubtype(subtype,[13,7, -20,-14])
lung.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Mucinous adenocarcinoma: 8480/3

# %%
subtype = 'Mucinous adenocarcinoma'
lung.prepareSubtype(subtype)

# %%
lung.analyzeSubtype(subtype,[3,2, -8,-3])
lung.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Acinar cell carcinoma: 8550/3

# %%
subtype = 'Acinar cell carcinoma'
lung.prepareSubtype(subtype)

# %%
lung.analyzeSubtype(subtype,[7,3, -14.5,-6.5])
lung.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Adenosquamous carcinoma: 8560/3

# %%
subtype = 'Adenosquamous carcinoma'
lung.prepareSubtype(subtype)

# %%
lung.analyzeSubtype(subtype,[8,3, -20,-10])
lung.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Conclusion

# %% [markdown]
# "Papillary adenocarcinoma" failed plotting. Excluded.
#
# Merge "Adenocarcinoma" and "Adenocarcinoma with mixed subtypes"
#
# Large cell carcinoama shows similar signature to small cell carcinoma, which does not make sense. After checking the original files, it appears half of the data is from one same study. I presume there are some bias or mistakes, therefore assign "Large Cell Carnicaoma to Carcinoma".

# %% [markdown]
# ## 2nd iteration, merge subtypes

# %%
lung = CancerType('Lung')

# %%
lung.countSubtypes()
# Out:
# [['80103' 84]
#  ['80123' 54]
#  ['80413' 155]
#  ['80463' 1725]
#  ['80701' 12]
#  ['80703' 518]
#  ['81403' 1103]
#  ['82403' 17]
#  ['82503' 24]
#  ['82523' 19]
#  ['82543' 18]
#  ['82553' 109]
#  ['82603' 29]
#  ['84803' 14]
#  ['85503' 21]
#  ['85603' 16]]

# %% [markdown]
# ```
# 8010/3: Carcinoma, NOS
# 8012/3: Large cell carcinoma, NOS
# 8041/3: Small cell carcinoma, NOS
# 8046/3: Non-small cell carcinoma
# 8070/1: Squamous cell carcinoma, uncertain
# 8070/3: Squamous cell carcinoma, NOS
# 8140/3: Adenocarcinoma
# 8240/3: Bronchial adenoma, carcinoid
# 8250/3: Bronchiolo-alveolar adenocarcinoma, NOS
# 8252/3: Bronchiolo-alveolar carcinoma, non-mucinous
# 8254/3: Bronchiolo-alveolar carcinoma, mixed mucinous and non-mucinous
# 8255/3: Adenocarcinoma with mixed subtypes
# 8260/3: Papillary adenocarcinoma, NOS
# 8480/3: Mucinous adenocarcinoma
# 8550/3: Acinar cell carcinoma
# 8560/3: Adenosquamous carcinoma
#  ```

# %% [markdown]
# merge "Adenocarcinoma" with "Adenocarcinoma with mixed subtypes"
#
# merge "Large cell carcinoma" with "Carcinoma"

# %%
code_remap = {
'80103': 'Carcinoma',
'80123': 'Carcinoma',
'80413': 'Small cell carcinoma',
'80463': 'Non-small cell carcinoma',
'80701': 'Squamous cell carcinoma uncertain',
'80703': 'Squamous cell carcinoma',
'81403': 'Adenocarcinoma',
'82403': 'Bronchial adenoma carcinoid',
'82503': 'Bronchiolo-alveolar adenocarcinoma',
'82523': 'Bronchiolo-alveolar carcinoma non-mucinous',
'82543': 'Bronchiolo-alveolar carcinoma mixed mucinous and non-mucinous',
'82553': 'Adenocarcinoma',
'82603': 'Papillary adenocarcinoma',
'84803': 'Mucinous adenocarcinoma',
'85503': 'Acinar cell carcinoma',
'85603': 'Adenosquamous carcinoma'
}

# %%
lung.relabel(code_remap)

# %%
lung.countSubtypes()
# Out:
# [['Acinar cell carcinoma' 21]
#  ['Adenocarcinoma' 1212]
#  ['Adenosquamous carcinoma' 16]
#  ['Bronchial adenoma carcinoid' 17]
#  ['Bronchiolo-alveolar adenocarcinoma' 24]
#  ['Bronchiolo-alveolar carcinoma mixed mucinous and non-mucinous' 18]
#  ['Bronchiolo-alveolar carcinoma non-mucinous' 19]
#  ['Carcinoma' 138]
#  ['Mucinous adenocarcinoma' 14]
#  ['Non-small cell carcinoma' 1725]
#  ['Papillary adenocarcinoma' 29]
#  ['Small cell carcinoma' 155]
#  ['Squamous cell carcinoma' 518]
#  ['Squamous cell carcinoma uncertain' 12]]

# %%
lung.dumpSubtypeCounts()

# %% [markdown]
# ### Adenocarcinoma: 8140/3, 8255/3

# %%
subtype = 'Adenocarcinoma'
lung.prepareSubtype(subtype)

# %%
lung.analyzeSubtype(subtype,[350,230, -480,-250])
lung.dumpSubtypeFiles(subtype)

# %%
subtype = 'Carcinoma'
lung.prepareSubtype(subtype)

# %%
lung.analyzeSubtype(subtype,[50,30, -70,-40])
lung.dumpSubtypeFiles(subtype)

# %%
subcounts = lung.countSubtypes()
# Out:
# [['Acinar cell carcinoma' 21]
#  ['Adenocarcinoma' 1212]
#  ['Adenosquamous carcinoma' 16]
#  ['Bronchial adenoma carcinoid' 17]
#  ['Bronchiolo-alveolar adenocarcinoma' 24]
#  ['Bronchiolo-alveolar carcinoma mixed mucinous and non-mucinous' 18]
#  ['Bronchiolo-alveolar carcinoma non-mucinous' 19]
#  ['Carcinoma' 84]
#  ['Large cell carcinoma' 54]
#  ['Mucinous adenocarcinoma' 14]
#  ['Non-small cell carcinoma' 1725]
#  ['Papillary adenocarcinoma' 29]
#  ['Small cell carcinoma' 155]
#  ['Squamous cell carcinoma' 518]
#  ['Squamous cell carcinoma uncertain' 12]]

# %%
subcounts = np.array(np.unique(lung.labels, return_counts=True)).T

# %%
subcounts[1,1]
# Out:
# 1212

# %%
pd.DataFrame(subcounts, columns=['name', 'count'])
# Out:
#                                                  name count
# 0                               Acinar cell carcinoma    21
# 1                                      Adenocarcinoma  1212
# 2                             Adenosquamous carcinoma    16
# 3                         Bronchial adenoma carcinoid    17
# 4                  Bronchiolo-alveolar adenocarcinoma    24
# 5   Bronchiolo-alveolar carcinoma mixed mucinous a...    18
# 6          Bronchiolo-alveolar carcinoma non-mucinous    19
# 7                                           Carcinoma    84
# 8                                Large cell carcinoma    54
# 9                             Mucinous adenocarcinoma    14
# 10                           Non-small cell carcinoma  1725
# 11                           Papillary adenocarcinoma    29
# 12                               Small cell carcinoma   155
# 13                            Squamous cell carcinoma   518
# 14                  Squamous cell carcinoma uncertain    12
