# %% [markdown]
# # Liver and subtypes

# %%
import numpy as np
import pandas as pd
import time
import os
import pickle
import sys
from importlib import reload


from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from utils import CancerType

# %% [markdown]
# ## 1st iteration, inspect each subtype

# %%
liver = CancerType('Liver')

# %%
liver.countSubtypes()
# Out:
# [['81703' 371]
#  ['C22' 253]
#  ['None' 27]]

# %% [markdown]
# ```
# 8170/3: Hepatocellular carcinoma, NOS
# ```

# %%
code_remap = {
    '81703': 'Hepatocellular carcinoma',
    'C22': 'Not specified',
    'None': 'Not specified'
}

# %%
liver.relabel(code_remap)

# %%
liver.countSubtypes()
# Out:
# [['Hepatocellular carcinoma' 371]
#  ['Not specified' 280]]

# %%
liver.dumpSubtypeCounts()

# %%
liver.pcaTSNE()
# Out:
# PCA done! Time elapsed: 0.12440681457519531 seconds
# Cumulative explained variation for 50 principal components: 0.9216182684807231
# t-SNE done! Time elapsed: 4.738232135772705 seconds

# %%
liver.groupData()

# %%
liver.analyze([250, 90, -300, -100])
liver.dumpFiles()

# %%
liver.countData()
# Out:
# amp_genes	(562, 9)
# del_genes	(260, 9)
# genes	562
# high_amp_genes	(73, 9)
# low_amp_genes	(489, 9)
# high_del_genes	(26, 9)
# low_del_genes	(234, 9)
# high_amp_census	(6, 9)
# low_amp_census	(12, 9)
# amp_census	(18, 9)
# high_del_census	(1, 9)
# low_del_census	(16, 9)
# del_census	(17, 9)
# census	35

# %% [markdown]
# ### Hepatocellular carcinoma: 8170/3

# %%
subtype = 'Hepatocellular carcinoma'
liver.prepareSubtype(subtype)

# %%
liver.analyzeSubtype(subtype,[170,60, -190,-60])
liver.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### conclusion

# %% [markdown]
# Only one subtype
