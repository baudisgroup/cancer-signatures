# %% [markdown]
# # Breast and subtypes

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
import numpy as np
import pandas as pd
import time
import os
import pickle
import sys
from importlib import reload


from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from utils import CancerType

# %% [markdown]
# ## Iteration 1, individual subtypes

# %%
breast = CancerType('Breast')

# %%
breast.countSubtypes()
# Out:
# [['80223' 14]
#  ['84803' 15]
#  ['85002' 82]
#  ['85003' 5657]
#  ['85073' 43]
#  ['85203' 201]
#  ['85223' 28]
#  ['85233' 14]
#  ['85303' 19]
#  ['85753' 16]
#  ['C50.4' 12]
#  ['C50.9' 11]
#  ['None' 66]]

# %% [markdown]
# ```
# 8022/3: Pleomorphic carcinoma
# 8480/3: Mucinous adenocarcinoma
# 8500/2: Intraductal carcinoma, noninfiltrating, NOS
# 8500/3: Infiltrating duct carcinoma, NOS
# 8507/3: Intraductal micropapillary carcinoma (8507/2)
# 8520/3: Lobular carcinoma, NOS
# 8522/3: Infiltrating duct and lobular carcinoma
# 8523/3: Infiltrating duct mixed with other types of carcinoma
# 8530/3: Inflammatory carcinoma
# 8575/3: Metaplastic carcinoma, NOS
# ```

# %%
code_remap = {
'80223': 'Pleomorphic carcinoma',
'84803': 'Mucinous adenocarcinoma',
'85002': 'Intraductal carcinoma',
'85003': 'Infiltrating duct carcinoma',
'85073': 'Intraductal micropapillary carcinoma',
'85203': 'Lobular carcinoma',
'85223': 'Infiltrating duct and lobular carcinoma',
'85233': 'Infiltrating duct mixed',
'85303': 'Inflammatory carcinoma',
'85753': 'Metaplastic carcinoma',
'C50.4': 'Not specified',
'C50.9': 'Not specified',
'None': 'Not specified'
}

# %%
breast.relabel(code_remap)

# %%
breast.countSubtypes()
# Out:
# [['Infiltrating duct and lobular carcinoma' 28]
#  ['Infiltrating duct carcinoma' 5657]
#  ['Infiltrating duct mixed' 14]
#  ['Inflammatory carcinoma' 19]
#  ['Intraductal carcinoma' 82]
#  ['Intraductal micropapillary carcinoma' 43]
#  ['Lobular carcinoma' 201]
#  ['Metaplastic carcinoma' 16]
#  ['Mucinous adenocarcinoma' 15]
#  ['Not specified' 89]
#  ['Pleomorphic carcinoma' 14]]

# %%
breast.dumpSubtypeCounts()

# %%
breast.pcaTSNE()
# Out:
# PCA done! Time elapsed: 0.5480811595916748 seconds
# Cumulative explained variation for 50 principal components: 0.824320637993026
# t-SNE done! Time elapsed: 68.8611330986023 seconds

# %%
breast.groupData()

# %%
breast.analyze([2500, 1400, -1800, -1200])
breast.dumpFiles()

# %%
breast.countData()
# Out:
# amp_genes	(104, 9)
# del_genes	(191, 9)
# genes	104
# high_amp_genes	(50, 9)
# low_amp_genes	(54, 9)
# high_del_genes	(38, 9)
# low_del_genes	(153, 9)
# high_amp_census	(5, 9)
# low_amp_census	(4, 9)
# amp_census	(9, 9)
# high_del_census	(2, 9)
# low_del_census	(5, 9)
# del_census	(7, 9)
# census	16

# %% [markdown]
# ### Pleomorphic carcinoma: 8022/3

# %%
subtype = 'Pleomorphic carcinoma'
breast.prepareSubtype(subtype)

# %%
breast.analyzeSubtype(subtype,[4,1, -7,-4])
breast.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Mucinous adenocarcinoma: 8480/3

# %%
subtype = 'Mucinous adenocarcinoma'
breast.prepareSubtype(subtype)

# %%
breast.analyzeSubtype(subtype,[4,2, -6,-3])
breast.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Intraductal carcinoma: 8500/2

# %%
subtype = 'Intraductal carcinoma'
breast.prepareSubtype(subtype)

# %%
breast.analyzeSubtype(subtype,[35,20, -30,-18])
breast.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Infiltrating duct carcinoma: 8500/3

# %%
subtype = 'Infiltrating duct carcinoma'
breast.prepareSubtype(subtype)

# %%
breast.analyzeSubtype(subtype,[2100,1400, -1700,-1100])
breast.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Intraductal micropapillary carcinoma: 8507/3

# %%
subtype = 'Intraductal micropapillary carcinoma'
breast.prepareSubtype(subtype)

# %%
breast.analyzeSubtype(subtype,[15,10, -16,-8])
breast.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Lobular carcinoma: 8520/3

# %%
subtype = 'Lobular carcinoma'
breast.prepareSubtype(subtype)

# %%
breast.analyzeSubtype(subtype,[75,30, -70,-40])
breast.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Infiltrating duct and lobular carcinoma: 8522/3

# %%
subtype = 'Infiltrating duct and lobular carcinoma'
breast.prepareSubtype(subtype)

# %%
breast.analyzeSubtype(subtype,[14,7, -20,-11])
breast.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Infiltrating duct mixed: 8523/3

# %%
subtype = 'Infiltrating duct mixed'
breast.prepareSubtype(subtype)

# %%
breast.analyzeSubtype(subtype,[7,4, -9,-4])
breast.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Inflammatory carcinoma: 8530/3

# %%
subtype = 'Inflammatory carcinoma'
breast.prepareSubtype(subtype)

# %%
breast.analyzeSubtype(subtype,[15,8, -13,-8])
breast.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Metaplastic carcinoma: 8575/3

# %%
subtype = 'Metaplastic carcinoma'
breast.prepareSubtype(subtype)

# %%
breast.analyzeSubtype(subtype,[9,5, -9,-5.5])
breast.dumpSubtypeFiles(subtype)

# %% [markdown]
# ### Conclusion

# %% [markdown]
# All subtypes show distinct signatures. No merging.
