# %%
from pymongo import MongoClient
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

import sys, os
sys.path.append('/Users/bogao/Desktop/projects/Relative copy number/Python/mecan')
import mecan4cna.algorithms as alg
import mecan4cna.common as comm
# Out:
# <style>.container { width:90% !important; }</style>

# %%
db = MongoClient()['Rebased']['mecaned']

# %%
sam = db.find_one({'sample_id':'PGX_AM_BS_GSM2078085'})

# %%
sam.keys()
# Out:
# dict_keys(['_id', 'source', 'project', 'sample_id', 'morphology', 'topography', 'stage', 'gender', 'age', 'vital_status', 'file_path', 'platform', 'segments', 'base', 'level_distance', 'normalized'])

# %%
comm.plotSegments(test_cyto[idx]['segments'])
